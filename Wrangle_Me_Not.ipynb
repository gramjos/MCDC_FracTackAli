# %%
import flickrapi, os, json, time
from flickrapi.exceptions import FlickrError
import pandas as pd
from dotenv import load_dotenv
from typing import Union, Dict, List

# Load variables defined in the local .env file. 
print(f"Local folder defined env variables found?.... {load_dotenv()=}")

# a recursively typed json object for ints, strs and lists
JSONVal = Union[str, int, 'JSONArray', 'JSONObject']
JSONArray = List[JSONVal]
JSONObject = Dict[str, JSONVal]
# Out:
# Local folder defined env variables found?.... load_dotenv()=True

# %%
# Load in dot env variables
secret : str = os.getenv('SECRET')
key : str = os.getenv('KEY')
USER_NAME : str = os.getenv('ORG_USER_NAME')

# %%
# Log in and create user ID object
flickr : flickr.FlickrAPI = flickrapi.FlickrAPI(key, secret, format='parsed-json')
# FracTracker Org Credentials
user_info : JSONObject = flickr.people.findByUsername(username=USER_NAME)
user_id : str = user_info['user']['id']

# %%
# get the list of Fracktracker's albums
photosets : JSONObject = flickr.photosets.getList(user_id=user_id)

# %%
album_ids : List[str] = [albumMetaData['id'] for albumMetaData in photosets['photosets']['photoset']]

# %%
start_entire = time.time()
attributes=[]
for a_id in album_ids:
    pg_start, pg_end, per_page = 1, 1, 500

    photos : JSONObject = flickr.photosets.getPhotos(photoset_id=a_id, page=pg_start, per_page=per_page)
    for pg in range(1, photos['photoset']['pages']+1):
        print(f"ON page {pg=} of album id {photos['photoset']['id']}")
        if pg!=1: photos : JSONObject = flickr.photosets.getPhotos(photoset_id=a_id, page=pg, per_page=per_page)
        print(f"\t On this page of the album there are {len(photos['photoset']['photo'])}")
        album_title = photos['photoset']['title']
        start = time.time()
        for pic in photos['photoset']['photo']:
            photo_id = pic['id']
            try:
                photo_info = flickr.photos.getInfo(photo_id=photo_id)['photo']
            except FlickrError as e:
                if 'Status code 500' in str(e):
                    print(f"Encountered an error for photo_id {photo_id}: {e}. waiting 2 seconds and then trying again")
                    time.sleep(2) 
                    photo_info = flickr.photos.getInfo(photo_id=photo_id)['photo']
                else:
                    print(f"Encountered an error for photo_id {photo_id}: {e}. Skipping this photo. waiting 2 seconds and then trying again")
                    time.sleep(2) 
                    photo_info = flickr.photos.getInfo(photo_id=photo_id)['photo']
        
            title = photo_info['title']['_content']
            description = photo_info['description']['_content']
            url = f"https://www.flickr.com/photos/fractracker/{photo_id}/in/album-{a_id}"
            dt=photo_info['dates']['taken']
            
            # Extract latitude and longitude if available
            latitude = None
            longitude = None
            if 'location' in photo_info:
                location_info = photo_info['location']
                if 'latitude' in location_info and 'longitude' in location_info:
                    latitude = location_info['latitude']
                    longitude = location_info['longitude']
            else : #skip records with no localtion
                continue
            attributes.append({'PhotoID': photo_id,'Title': title, 'Date_taken': dt,'Description': description,'URL': url,
                'Latitude': latitude,'Longitude': longitude,'AlbumID': a_id,'AlbumTitle': album_title})
        end = time.time()
        elapsed = end - start
        elapsed_since_st = end - start_entire
        elapsed_since_st_MIN = elapsed_since_st/60
        print(f'\tTime taken for this page: {elapsed:.6f} seconds') 
        print(f'\tTime taken since code start: {elapsed_since_st:.6f} seconds') 
        print(f'\tTime taken since code start: {elapsed_since_st_MIN:.6f} min') 
            
end_entire = time.time()
elapsed_entire = end_entire - start_entire
minn = elapsed_entire/60
print(f'Time taken for this entire snippet: {elapsed_entire:.6f} seconds')    
print(f'Time taken for this entire snippet: {minn:.6f} seconds')
# Out:
# ON page pg=1 of album id 72157715916543893
# 	 On this page of the album there are 500
# 	Time taken for this page: 144.489284 seconds
# 	Time taken since code start: 145.306736 seconds
# 	Time taken since code start: 2.421779 min
# ON page pg=2 of album id 72157715916543893
# 	 On this page of the album there are 500
# 	Time taken for this page: 138.659861 seconds
# 	Time taken since code start: 285.017826 seconds
# 	Time taken since code start: 4.750297 min
# ON page pg=3 of album id 72157715916543893
# 	 On this page of the album there are 99
# 	Time taken for this page: 28.831605 seconds
# 	Time taken since code start: 314.116588 seconds
# 	Time taken since code start: 5.235276 min
# ON page pg=1 of album id 72157718955813667
# 	 On this page of the album there are 40
# 	Time taken for this page: 10.179086 seconds
# 	Time taken since code start: 324.860964 seconds
# 	Time taken since code start: 5.414349 min
# ON page pg=1 of album id 72157715839488573
# 	 On this page of the album there are 500
# 	Time taken for this page: 148.118397 seconds
# 	Time taken since code start: 473.491193 seconds
# 	Time taken since code start: 7.891520 min
# ON page pg=2 of album id 72157715839488573
# 	 On this page of the album there are 123
# 	Time taken for this page: 37.900063 seconds
# 	Time taken since code start: 511.631433 seconds
# 	Time taken since code start: 8.527191 min
# ON page pg=1 of album id 72157714012190006
# 	 On this page of the album there are 100
# 	Time taken for this page: 27.267247 seconds
# 	Time taken since code start: 539.233220 seconds
# 	Time taken since code start: 8.987220 min
# ON page pg=1 of album id 72157714222642517
# 	 On this page of the album there are 500
# 	Time taken for this page: 128.675575 seconds
# 	Time taken since code start: 668.248872 seconds
# 	Time taken since code start: 11.137481 min
# ON page pg=2 of album id 72157714222642517
# 	 On this page of the album there are 86
# 	Time taken for this page: 24.650560 seconds
# 	Time taken since code start: 693.225470 seconds
# 	Time taken since code start: 11.553758 min
# ON page pg=1 of album id 72157714265378312
# 	 On this page of the album there are 500
# 	Time taken for this page: 144.723832 seconds
# 	Time taken since code start: 838.439453 seconds
# 	Time taken since code start: 13.973991 min
# ON page pg=2 of album id 72157714265378312
# 	 On this page of the album there are 248
# 	Time taken for this page: 70.441535 seconds
# 	Time taken since code start: 909.341765 seconds
# 	Time taken since code start: 15.155696 min
# ON page pg=1 of album id 72157713782049298
# 	 On this page of the album there are 232
# 	Time taken for this page: 91.738605 seconds
# 	Time taken since code start: 1001.454421 seconds
# 	Time taken since code start: 16.690907 min
# ON page pg=1 of album id 72157715838976098
# 	 On this page of the album there are 500
# 	Time taken for this page: 170.683480 seconds
# 	Time taken since code start: 1172.849520 seconds
# 	Time taken since code start: 19.547492 min
# ON page pg=2 of album id 72157715838976098
# 	 On this page of the album there are 261
# 	Time taken for this page: 71.933925 seconds
# 	Time taken since code start: 1245.197573 seconds
# 	Time taken since code start: 20.753293 min
# ON page pg=1 of album id 72157713999613671
# 	 On this page of the album there are 500
# Out:
# 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!'

# %%
df['Title'].iloc[0]
# Out:
# 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023'

# %%
type(df['PhotoID'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df['PhotoID'].value_counts() # get a sense of the duplicate photo ids
# Out:
# PhotoID
# 53184405947    17
# 53185048804    17
# 53184985776    17
# 53185189725    17
# 53185356068    17
#                ..
# 52405982252     2
# 51438195404     1
# 51437688658     1
# 51438414330     1
# 51438414365     1
# Name: count, Length: 2718, dtype: int64

# %%
df['Description'].value_counts() # get a sense of the duplicate descriptions
# Out:
# Description
# Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                               6497
# Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                         2107
# Photo citation: Ted Auch, 2022. Photo courtesy of FracTracker Alliance.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                             1829
# Photo citation: Ted Auch, FracTracker Alliance, 2021. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                         1405
# Photo citation: Ted Auch, FracTracker Alliance, 2018.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                               1151
# Photo citation: Ted Auch, FracTracker Alliance, 2020.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                               1142
# Photo citation: Ted Auch, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                               1059
# Photo citation: Ted Auch, FracTracker Alliance, 2019.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                                563
# Photo citation: Ted Auch, FracTracker Alliance, 2016.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                                510
# Photo citation: Ted Auch, FracTracker Alliance, 2017.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                                478
# Photo citation: Ted Auch, FracTracker Alliance, 2015.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                                430
# Photo citation: Ted Auch, FracTracker Alliance, 2024.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                                399
# Photo citation: Ted Auch, FracTracker Alliance, 2018. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                          132
# Photo citation: Ted Auch, FracTracker Alliance, 2016. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                          114
# Photo citation: Shannon Smith, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                           104
# Photo citation: Rebecca Johnson, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                          71
# Photo citation: Erica Jackson, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                            64
# Photo citation: Matt Kelso, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                               64
# Photo citation: Ted Auch, FracTracker Alliance, 2013.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                                 50
# Photo citation: Karen Edelstein, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                          35
# Dick Martin, 2021. Photo courtesy of FracTracker Alliance.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                            28
# This site includes a very active flare stack and mini-compressors.\n\nPhoto citation: Ted Auch, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!           20
# This drone photo was taken from the Young horse farm in the foreground.\n\nPhoto citation: Ted Auch, FracTracker Alliance, 2021.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!      20
# ...
# Photo citation: Mary Whipple, 2017. Photo courtesy of FracTracker Alliance.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                            2
# Photo citation: Brook Lenker, FracTracker Alliance, 2013.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                              2
# Photo citation: Brook Lenker, FracTracker Alliance, 2013.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                              2
# Photo citation: Brook Lenker, FracTracker Alliance, 2013.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                              2
# Photo citation: Brook Lenker, FracTracker Alliance, 2013.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                              2
# Ric Zarwell, 2014. Photo courtesy of FracTracker Alliance\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                              2
# Linda Daul, 2014. Photo courtesy of FracTracker Alliance\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!                                                                               2
# Name: count, dtype: int64

# %%
len(df['Description'].value_counts()) #  47 types of Descipts
# Out:
# 47

# %%
df.dtypes
# Out:
# PhotoID        object
# Title          object
# Date_taken     object
# Description    object
# URL            object
# Latitude       object
# Longitude      object
# AlbumID        object
# AlbumTitle     object
# dtype: object

# %%
grouped_df = df.groupby('PhotoID')['AlbumTitle'].agg(list).reset_index()
grouped_df  # notice the length of this dataframe matches the length of df['PhotoID'].value_counts() from above
# Out:
#           PhotoID                                         AlbumTitle
# 0     49727911618                      [Frac Sand Mining, Wisconsin]
# 1     49727914298  [Frac Sand Mining, Illinois, Impoundment Ponds...
# 2     49727914638  [Frac Sand Mining, Frac Sand Transportation, I...
# 3     49727915018  [Frac Sand Mining, Illinois, Impoundment Ponds...
# 4     49727915083  [Frac Sand Mining, Illinois, Impoundment Ponds...
# ...           ...                                                ...
# 2713  53706158340  [Communities, Culture & Livelihoods, Environme...
# 2714  53706158375  [Communities, Culture & Livelihoods, Environme...
# 2715  53706158545  [Communities, Culture & Livelihoods, Environme...
# 2716  53706158630  [Communities, Culture & Livelihoods, Environme...
# 2717  53706158655  [Communities, Culture & Livelihoods, Environme...
#
# [2718 rows x 2 columns]

# %%
# piece back the dataframes attriubtes w/o 'AlbumTitle'
df = df.drop(['AlbumTitle','AlbumID'], axis=1)
df = df.drop_duplicates(subset='PhotoID', keep='first')  # loose description corresponse 
df
# Out:
#            PhotoID                                              Title  \
# 0      52748254383  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 1      52748254428  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 2      52748254463  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 3      52748172745  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 4      52748007544  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# ...            ...                                                ...
# 11686  49834943141  TAuch_Transportation-Waste_BrineHauler-Malaga_...
# 12345  52404379539  TAuch_Infrastructure-Water_Pipeline_GaiaPad-We...
# 16784  51438195404  TAuch_Infrastructure_Ship-SarniaHarbor-Ontario...
# 16785  51438414330  TAuch_Infrastructure_Ship-SarniaHarbor-StClair...
# 16786  51438414365  TAuch_Infrastructure_Ship-SarniaHarbor-StClair...
#
#                 Date_taken                                        Description  \
# 0      2023-03-09 12:24:13  Photo citation: Ted Auch, FracTracker Alliance...
# 1      2023-03-09 12:19:38  Photo citation: Ted Auch, FracTracker Alliance...
# 2      2023-03-09 12:18:49  Photo citation: Ted Auch, FracTracker Alliance...
# 3      2023-03-09 12:18:29  Photo citation: Ted Auch, FracTracker Alliance...
# 4      2023-03-09 12:17:51  Photo citation: Ted Auch, FracTracker Alliance...
# ...                    ...                                                ...
# 11686  2017-05-03 11:52:06  Photo citation: Ted Auch, FracTracker Alliance...
# 12345  2022-09-30 09:51:45  Photo citation: Ted Auch, 2022. Photo courtesy...
# 16784  2021-09-03 09:42:49  Photo citation: Ted Auch, FracTracker Alliance...
# 16785  2021-09-03 09:42:33  Photo citation: Ted Auch, FracTracker Alliance...
# 16786  2021-09-03 09:42:27  Photo citation: Ted Auch, FracTracker Alliance...
#
#                                                      URL   Latitude  \
# 0      https://www.flickr.com/photos/fractracker/5274...  40.631783
# 1      https://www.flickr.com/photos/fractracker/5274...  40.630638
# 2      https://www.flickr.com/photos/fractracker/5274...  40.631202
# 3      https://www.flickr.com/photos/fractracker/5274...  40.630791
# 4      https://www.flickr.com/photos/fractracker/5274...  40.631625
# ...                                                  ...        ...
# 11686  https://www.flickr.com/photos/fractracker/4983...  39.868114
# 12345  https://www.flickr.com/photos/fractracker/5240...  40.377602
# 16784  https://www.flickr.com/photos/fractracker/5143...  42.983333
# 16785  https://www.flickr.com/photos/fractracker/5143...  42.985735
# 16786  https://www.flickr.com/photos/fractracker/5143...  42.988600
#
#         Longitude
# 0      -80.546412
# 1      -80.545881
# 2      -80.545584
# 3      -80.545256
# 4      -80.546289
# ...           ...
# 11686  -81.176025
# 12345  -79.626473
# 16784  -82.418811
# 16785  -82.421514
# 16786  -82.422899
#
# [2718 rows x 7 columns]

# %%
# notice the length of df and grouped_df...time to join
merged_df = pd.merge(grouped_df, df, on='PhotoID', how='left')
merged_df
# Out:
#           PhotoID                                         AlbumTitle  \
# 0     49727911618                      [Frac Sand Mining, Wisconsin]
# 1     49727914298  [Frac Sand Mining, Illinois, Impoundment Ponds...
# 2     49727914638  [Frac Sand Mining, Frac Sand Transportation, I...
