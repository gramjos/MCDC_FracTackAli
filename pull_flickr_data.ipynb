# %%
import flickrapi, os, json, time
import pandas as pd
from dotenv import load_dotenv
from typing import Union, Dict, List

# Load variables defined in the local .env file. 
print(f"Local folder defined env variables found?.... {load_dotenv()=}")

# a recursively typed json object for ints, strs and lists
JSONVal = Union[str, int, 'JSONArray', 'JSONObject']
JSONArray = List[JSONVal]
JSONObject = Dict[str, JSONVal]
# Out:
# Local folder defined env variables found?.... load_dotenv()=True

# %%
# Load in dot env variables
secret = os.getenv('SECRET')
key = os.getenv('KEY')
USER_NAME = os.getenv('ORG_USER_NAME')

# %%
# Log in and create user ID object
flickr = flickrapi.FlickrAPI(key, secret, format='parsed-json')

# %%
# FracTracker Org Credentials
user_info : JSONObject = flickr.people.findByUsername(username=USER_NAME)
user_id = user_info['user']['id']
user_id
# Out:
# '186454571@N08'

# %%
user_info
# Out:
# {'user': {'id': '186454571@N08',
#   'nsid': '186454571@N08',
#   'username': {'_content': 'FracTracker_Alliance'}},
#  'stat': 'ok'}

# %%
# get the list of Fracktracker's albums
# album URL https://www.flickr.com/photos/fractracker/albums/with/72157713930235593
photosets : JSONObject = flickr.photosets.getList(user_id=user_id)

# %%
pic_ct_per_album = {attr['title']['_content']:attr['count_photos'] for attr in photosets['photosets']['photoset']}
pic_ct_per_album
# Out:
# {'Appalachian Buildout': 1099,
#  'California': 39,
#  'Channels of Life: the Gulf Coast Buildout in TX': 623,
#  'Coal Mining': 100,
#  'Coastal & Marine Environments': 586,
#  'Communities': 747,
#  'Compressor Stations': 231,
#  'Construction': 761,
#  'Cracker Plants & Ethylene': 541,
#  'Culture & Livelihoods': 316,
#  'Drilling & Fracking': 609,
#  'East Palestine Train Derailment': 62,
#  'Endless Effects: the Loyalsock Watershed Project': 53,
#  'Environmental Justice': 652,
#  'Explosions, Fires, & Flaring': 158,
#  'Forests': 125,
#  'Frac Sand Mining': 509,
#  'Frac Sand Storage & Processing': 430,
#  'Frac Sand Transportation': 268,
#  'Freshwater Ecosystems': 365,
#  'Grasslands & Prairies': 75,
#  'Gulf Coast Buildout': 598,
#  'Illinois': 119,
#  'Impoundment Ponds': 254,
#  'Injection Wells': 169,
#  'Land Preservation & Management': 105,
#  'Louisiana': 370,
#  'Marshes, Swamps, & Wetlands': 472,
#  'Maryland': 9,
#  'Methane & Air and Water Quality Concerns': 1017,
#  'Michigan': 393,
#  'Minnesota': 68,
#  'Movement Building': 55,
#  'Netherlands': 11,
#  'North Dakota': 47,
#  'Offshore Drilling': 406,
#  'Ohio': 777,
#  'Pennsylvania': 626,
#  'Pipelines': 348,
#  'Plastics & Petrochemicals': 763,
#  'Pollution, Toxins, & Disposal Concerns': 1410,
#  'Power Plants': 145,
#  'Refineries & Processing': 773,
#  'Southeastern Michigan Sand Mining & Industrial Impacts': 186,
#  'Storage': 372,
#  'Texas': 623,
#  'Transportation': 427,
#  'Waste & Wastewater': 553,
#  'Water at Risk: the Lycoming Creek Watershed Project': 100,
#  'West Virginia': 137,
#  'Wildlife': 56,
#  'Wildness Lost: the Pine Creek Watershed Project': 184,
#  'Wind Energy': 35,
#  'Wisconsin': 414,
#  'Videos': 0}

# %%
with open('photosets.json', 'w') as file:
    json.dump(photosets, file, indent=4)

# %%
# album count
len(photosets['photosets']['photoset'])
# Out:
# 55

# %%
# Demonstrate how to find the album names.
# photosets['photosets']['photoset'][0] returns one album
for attr in photosets['photosets']['photoset'][0]:
    if attr == 'title':
        print(attr)
        print(photosets['photosets']['photoset'][0][attr])
        print(photosets['photosets']['photoset'][0][attr]['_content'])
        print(type(photosets['photosets']['photoset'][0][attr]['_content']))
# Out:
# title
# {'_content': 'Appalachian Buildout'}
# Appalachian Buildout
# <class 'str'>

# %%
# Verify that we understand the JSON structure. Important for define it's type
should_be_55=0

for albumMetaData in photosets['photosets']['photoset']:
        print(albumMetaData['title']['_content'])
        should_be_55+=1
# Out:
# Appalachian Buildout
# California
# Channels of Life: the Gulf Coast Buildout in TX
# Coal Mining
# Coastal & Marine Environments
# Communities
# Compressor Stations
# Construction
# Cracker Plants & Ethylene
# Culture & Livelihoods
# Drilling & Fracking
# East Palestine Train Derailment
# Endless Effects: the Loyalsock Watershed Project
# Environmental Justice
# Explosions, Fires, & Flaring
# Forests
# Frac Sand Mining
# Frac Sand Storage & Processing
# Frac Sand Transportation
# Freshwater Ecosystems
# Grasslands & Prairies
# Gulf Coast Buildout
# Illinois
# Impoundment Ponds
# Injection Wells
# Land Preservation & Management
# Louisiana
# Marshes, Swamps, & Wetlands
# Maryland
# Methane & Air and Water Quality Concerns
# Michigan
# Minnesota
# Movement Building
# Netherlands
# North Dakota
# Offshore Drilling
# Ohio
# Pennsylvania
# Pipelines
# Plastics & Petrochemicals
# Pollution, Toxins, & Disposal Concerns
# Power Plants
# Refineries & Processing
# Southeastern Michigan Sand Mining & Industrial Impacts
# Storage
# Texas
# Transportation
# Waste & Wastewater
# Water at Risk: the Lycoming Creek Watershed Project
# West Virginia
# Wildlife
# Wildness Lost: the Pine Creek Watershed Project
# Wind Energy
# Wisconsin
# Videos

# %%
album_titles : List[str] = [albumMetaData['title']['_content'] for albumMetaData in photosets['photosets']['photoset']]

# %%
album_ids : List[str] = [albumMetaData['id'] for albumMetaData in photosets['photosets']['photoset']]

# %%
should_be_55==len(photosets['photosets']['photoset'])==len(album_ids)==len(album_titles)==55
# Out:
# True

# %% [markdown]
# ### a demonstrative example
# In Flickr lingo, an album is a photoset. The API call...
# ```python
# photosets : JSONObject = flickr.photosets.getList(user_id=user_id) ;
# ```
# The above returns, meta data about each album and a small amount of meta data about the all the albums.
# ##### Understanding the response
# ###### Meta data about the call itself
# ```json
# {
#     "photosets": {
#         "page": 1,
#         "pages": 1,
#         "perpage": 500,
#         "total": 55,
#         "photoset": [
#             ...
#         ]
#     },
#         "stat": "ok"
#
# }
# ```
# We interpret the above response as, this is the first page of albums (`"page": 1,`) of one page (`"pages": 1,`). There can be up to 500 albums per page (`"perpage": 500,`). This page has 55 albums (`"total": 55,`). The attribute photoset is a list containing meta-data about each album (`"photoset": [...]`).
# ##### Meta data about the albums
# Below is the information provided for each album. There are 55 instances of the below attriubte becuase there are 55 albums. This data is in the ellipsis of the above snippet (`"photoset": [...]`).
# ```json
#             {
#                 "id":,
#                 "owner":,
#                 "username":,
#                 "primary":,
#                 "secret":,
#                 "server":,
#                 "farm":,
#                 "count_views":,
#                 "count_comments":,
#                 "count_photos":,
#                 "count_videos":,
#                 "title": {
#                     "_content":
#                 },
#                 "description": {
#                     "_content":
#                 },
#                 "can_comment": ,
#                 "date_create":,
#                 "date_update":,
#                 "sorting_option_id":,
#                 "photos":,
#                 "videos":,
#                 "visibility_can_see_set":,
#                 "needs_interstitial":
#             }
#
# ```
# Values to each of the above atrriubtes are either `int`, `str`, or `dict`. The only `list` in the JSON reponse is the one containing the albums.
# The `"id"` attriubte is used to find the assets (images or videos) within each album.
# ### Lets create a list of all the album `id`s (this list should be 55 elements long).

# %%
# dry run... print one id

for attr in photosets['photosets']['photoset'][0]:
    if attr == 'id':
        print(photosets['photosets']['photoset'][0][attr])
        print(type(photosets['photosets']['photoset'][0][attr]))
# Out:
# 72157715916543893
# <class 'str'>

# %%
album_ids = list()

for attr in photosets['photosets']['photoset']:
    print(f" adding {attr['id']} to list of albums ids. list is currently {len(album_ids)}")
    album_ids.append(attr['id'])
# Out:
#  adding 72157715916543893 to list of albums ids. list is currently 0
#  adding 72157718955813667 to list of albums ids. list is currently 1
#  adding 72157715839488573 to list of albums ids. list is currently 2
#  adding 72157714012190006 to list of albums ids. list is currently 3
#  adding 72157714222642517 to list of albums ids. list is currently 4
#  adding 72157714265378312 to list of albums ids. list is currently 5
#  adding 72157713782049298 to list of albums ids. list is currently 6
#  adding 72157715838976098 to list of albums ids. list is currently 7
#  adding 72157713999613671 to list of albums ids. list is currently 8
#  adding 72157714221113491 to list of albums ids. list is currently 9
#  adding 72157713805087661 to list of albums ids. list is currently 10
#  adding 72177720306424638 to list of albums ids. list is currently 11
#  adding 72157715400012723 to list of albums ids. list is currently 12
#  adding 72177720305148733 to list of albums ids. list is currently 13
#  adding 72157713930502332 to list of albums ids. list is currently 14
#  adding 72157714220749338 to list of albums ids. list is currently 15
#  adding 72157713728924116 to list of albums ids. list is currently 16
#  adding 72157713730887622 to list of albums ids. list is currently 17
#  adding 72157713731035312 to list of albums ids. list is currently 18
#  adding 72157714264815182 to list of albums ids. list is currently 19
#  adding 72157714219325946 to list of albums ids. list is currently 20
#  adding 72157715920413807 to list of albums ids. list is currently 21
#  adding 72157715916568803 to list of albums ids. list is currently 22
#  adding 72157713806725802 to list of albums ids. list is currently 23
#  adding 72157713930554732 to list of albums ids. list is currently 24
#  adding 72157714264121333 to list of albums ids. list is currently 25
#  adding 72177720311125662 to list of albums ids. list is currently 26
#  adding 72157714221354791 to list of albums ids. list is currently 27
#  adding 72157718921606654 to list of albums ids. list is currently 28
#  adding 72157715464249628 to list of albums ids. list is currently 29
#  adding 72157715920439827 to list of albums ids. list is currently 30
#  adding 72157715915957951 to list of albums ids. list is currently 31
#  adding 72177720317407832 to list of albums ids. list is currently 32
#  adding 72157718942786524 to list of albums ids. list is currently 33
#  adding 72157718942577569 to list of albums ids. list is currently 34
#  adding 72157713930010868 to list of albums ids. list is currently 35
#  adding 72157715915967486 to list of albums ids. list is currently 36
#  adding 72157715920470247 to list of albums ids. list is currently 37
#  adding 72157713805048161 to list of albums ids. list is currently 38
#  adding 72157713984535282 to list of albums ids. list is currently 39
#  adding 72157715463318091 to list of albums ids. list is currently 40
#  adding 72157713989079177 to list of albums ids. list is currently 41
#  adding 72157713781640132 to list of albums ids. list is currently 42
#  adding 72157716022446731 to list of albums ids. list is currently 43
#  adding 72157713930235593 to list of albums ids. list is currently 44
#  adding 72157715916673993 to list of albums ids. list is currently 45
#  adding 72157713930235603 to list of albums ids. list is currently 46
#  adding 72157713808403752 to list of albums ids. list is currently 47
#  adding 72157719563309294 to list of albums ids. list is currently 48
#  adding 72157715916047551 to list of albums ids. list is currently 49
#  adding 72157714219542801 to list of albums ids. list is currently 50
#  adding 72157715839176878 to list of albums ids. list is currently 51
#  adding 72157713808860567 to list of albums ids. list is currently 52
#  adding 72157715920546937 to list of albums ids. list is currently 53
#  adding 72157716857731186 to list of albums ids. list is currently 54

# %%
# Same as above
a_ids = [attr['id'] for attr in photosets['photosets']['photoset']]
len(a_ids)
# Out:
# 55

# %%
len(album_ids)
# Out:
# 55

# %%
len(set(album_ids)) # sanity check, any duplicates?
# Out:
# 55

# %%
a_single_album = album_ids[0]

# %%
# %%time
pic_list =[]
pic_set=set()
pic_ppl_list =[]
pic_ppl_set=set()

#scrape images from photosets and collect unique photo IDs
# Go thruough the list of albums and save each albums id (photoset id). We will use each album id to 
## retrieve the assets of the album
for photoset_id in album_ids:

    #make list of photos in the photoset
    photos = flickr.photosets.getPhotos(photoset_id=photoset_id)

    #find unique photo IDs
    for photo in photos['photoset']['photo']:
        photo_id = photo['id']
        pic_list.append(photo_id)
        pic_set.add(photo_id)

#scrape images from individual uploads and collect unique photo IDs
## another location outsite of albums where assets were uploaded
individual_photos = flickr.people.getPhotos(user_id=user_id, per_page=500)

for photo in individual_photos['photos']['photo']:
    photo_id = photo['id']
    pic_ppl_list.append(photo_id)
    pic_ppl_set.add(photo_id)
# Out:
# CPU times: user 297 ms, sys: 51.5 ms, total: 348 ms
# Wall time: 23.5 s

# %%
len(pic_list),len(pic_set),len(pic_ppl_list),len(pic_ppl_set)
# Out:
# (16121, 3128, 500, 500)

# %%
# union sets
grand_pic_set : set[str] = pic_set | pic_ppl_set

# %%
len(grand_pic_set)
# Out:
# 3130

# %% [markdown]
# ## Open Question
# _why does `flickr.photosets.getPhotos` and `flickr.people.getPhotos` both need to be used?_ ...just for 2 assets?

# %%
# recall the namespace
# %whos
# Out:
# Variable            Type                    Data/Info
# -----------------------------------------------------
# Dict                _SpecialGenericAlias    typing.Dict
# JSONArray           _GenericAlias           typing.List[typing.Union[<...>orwardRef('JSONObject')]]
# JSONObject          _GenericAlias           typing.Dict[str, typing.U<...>orwardRef('JSONObject')]]
# JSONVal             _UnionGenericAlias      typing.Union[str, int, Fo<...>ForwardRef('JSONObject')]
# List                _SpecialGenericAlias    typing.List
# USER_NAME           str                     FracTracker_Alliance
# Union               _SpecialForm            typing.Union
# a_ids               list                    n=55
# a_single_album      str                     72157715916543893
# albumMetaData       dict                    n=21
# album_ids           list                    n=55
# album_titles        list                    n=55
# attr                dict                    n=21
# file                TextIOWrapper           <_io.TextIOWrapper name='<...>ode='w' encoding='UTF-8'>
# flickr              FlickrAPI               [FlickrAPI for key "0de0f<...>cd1646f8cfb4d766c2878fb"]
# flickrapi           module                  <module 'flickrapi' from <...>s/flickrapi/__init__.py'>
# grand_pic_set       set                     {'53182963721', '49884253<...>10972412', '50200309402'}
# individual_photos   dict                    n=2
# json                module                  <module 'json' from '/Use<...>on3.12/json/__init__.py'>
# key                 str                     0de0fe957cd1646f8cfb4d766c2878fb
# load_dotenv         function                <function load_dotenv at 0x10965ede0>
# os                  module                  <module 'os' (frozen)>
# pd                  module                  <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# photo               dict                    n=9
# photo_id            str                     53148471078
# photos              dict                    n=2
# photoset_id         str                     72157716857731186
# photosets           dict                    n=2
# pic_list            list                    n=16121
# pic_ppl_list        list                    n=500
# pic_ppl_set         set                     {'53182963721', '53181049<...>68967986', '53169410150'}
# pic_set             set                     {'53182963721', '49884253<...>10972412', '50200309402'}
# secret              str                     b9f5ed4542442d6e
# should_be_55        int                     55
# time                module                  <module 'time' (built-in)>
# user_id             str                     186454571@N08
# user_info           dict                    n=2

# %% [markdown]
# ### Pull the all the assets from an album
# Given the credentialed API object `flickr` the function call `photosets.getPhotos(photoset_id, per_page, page)` will return a similar `JSONObject`. Each asset is denoted as the following JSON
# ```json
# {'id': '52748254383',
#     'secret': '814202740b',
#     'server': '65535',
#     'farm': 66,
#     'title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#     'isprimary': '0',
#     'ispublic': 1,
#     'isfriend': 0,
#     'isfamily': 0}
# ```
# There are up to 500 of the above chunks (which correspond to an asset) in a single `photosets.getPhotos()` call. With the asset's `id` value one can use `photos.getInfo(photo_id)` to retrieve complete meta data. The exhaustive attribute list is below
#
# ```json
# {
#   'photo': {'id': '',
#   'secret': '',
#   'server': '',
#   'farm': ,
#   'dateuploaded': '',
#   'isfavorite': ,
#   'license': '',
#   'safety_level': '',
#   'rotation': ,
#   'originalsecret': '',
#   'originalformat': '',
#   'owner': {},
#   'title': {},
#   'description': {},
#   'visibility': {},
#   'dates': {},
#   'views': '',
#   'editability': {},
#   'publiceditability': {},
#   'usage': {},
#   'comments': {},
#   'notes': {},
#   'people': {},
#   'tags': {},
#   'location': {'latitude': '',
#    'longitude': '',
#    'accuracy': '',
#    'context': '',
#    'locality': {},
#    'county': {},
#    'region': {},
#    'country': {},
#    'neighbourhood': {}},
#   'geoperms': {},
#   'urls': {},
#   'media': ''},
#  'stat': ''
# }
# ```
# Before and after the series of assets (`'photo': [...]`) contained in a page there is meta data. Before the series of assets there is album id (`id`), etc... After the assets tell you what page of the album the data corresponds to, how many assets per page (`per_page`), total possible assets per page (`perpage`), total assets of the album (`total`), etc...
# ```json
# {'id': '72157715916543893',
#   'primary': '49834137413',
#   'owner': '186454571@N08',
#   'ownername': 'FracTracker_Alliance',
#   'photo': [...],
#   'page': '1',
#   'per_page': 500,
#   'perpage': 500,
#   'pages': 3,
#   'title': 'Appalachian Buildout',
#   'sorting_option_id': 'manual-add-to-end',
#   'total': 1099},
#  'stat': 'ok'}
#  ```
# ### For a single album, pull all assets

# %%
photos : JSONObject = flickr.photosets.getPhotos(photoset_id=a_single_album)
with open('photos.json', 'w') as file:
    json.dump(photosets, file, indent=4)

# %%
pg_start,pg_end = photos['photoset']['page'],photos['photoset']['pages']

# %%
start = time.time()

# for a single page of the single album
photos = flickr.photosets.getPhotos(photoset_id=a_single_album, per_page=500, page=1)

attributes = []
album_title = photos['photoset']['title']

# Create photo_info dictionary
for photo in photos['photoset']['photo']:
    photo_id = photo['id']
    photo_info = flickr.photos.getInfo(photo_id=photo_id)['photo']

    # Extract basic attributes
    title = photo_info['title']['_content']
    description = photo_info['description']['_content']
    url = f"https://www.flickr.com/photos/fractracker/{photo_id}/in/album-{a_single_album}"

    # Extract latitude and longitude if available
    latitude = None
    longitude = None
    if 'location' in photo_info:
        location_info = photo_info['location']
        if 'latitude' in location_info and 'longitude' in location_info:
            latitude = location_info['latitude']
            longitude = location_info['longitude']

    attributes.append({
        'PhotoID': photo_id,
        'Title': title,
        'Description': description,
        'URL': url,
        'Latitude': latitude,
        'Longitude': longitude,
        'AlbumID': a_single_album,
        'AlbumTitle': album_title
    })

end = time.time()
elapsed = end - start
print(f'Time taken: {elapsed:.6f} seconds')
# Out:
# Time taken: 130.976738 seconds

# %%
pic_ct_per_album = {attr['title']['_content']:attr['count_photos'] for attr in photosets['photosets']['photoset']}
pic_ct_per_album

# %%
x=sum(pic_ct_per_album.values())

# %%
# Given, 500 photos took 241 sec
((x/500)*elapsed)/60
# Out:
# 88.93757113891442

# %%
attributes
# Out:
# [{'PhotoID': '52748254383',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748254383/in/album-72157715916543893',
#   'Latitude': '40.631783',
#   'Longitude': '-80.546412',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748254428',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748254428/in/album-72157715916543893',
#   'Latitude': '40.630638',
#   'Longitude': '-80.545881',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748254383',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748254383/in/album-72157715916543893',
#   'Latitude': '40.631783',
#   'Longitude': '-80.546412',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748254428',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748254428/in/album-72157715916543893',
#   'Latitude': '40.630638',
#   'Longitude': '-80.545881',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748254463',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748254463/in/album-72157715916543893',
#   'Latitude': '40.631202',
#   'Longitude': '-80.545584',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748172745',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748172745/in/album-72157715916543893',
#   'Latitude': '40.630791',
#   'Longitude': '-80.545256',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748007544',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748007544/in/album-72157715916543893',
#   'Latitude': '40.631625',
#   'Longitude': '-80.546289',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748254623',
#   'Title': 'TAuch_Infrastructure-Heritage_HazardousWaste_Incinerator-ColumbianaCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748254623/in/album-72157715916543893',
#   'Latitude': '40.630994',
#   'Longitude': '-80.546578',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748005194',
#   'Title': 'TAuch_Infrastructure-Ross_HazardousWaste_Incinerator-LorainCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748005194/in/album-72157715916543893',
#   'Latitude': '41.323641',
#   'Longitude': '-82.033612',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52747231757',
#   'Title': 'TAuch_Infrastructure-Ross_HazardousWaste_Incinerator-LorainCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52747231757/in/album-72157715916543893',
#   'Latitude': '41.324058',
#   'Longitude': '-82.032987',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748005319',
#   'Title': 'TAuch_Infrastructure-Ross_HazardousWaste_Incinerator-LorainCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748005319/in/album-72157715916543893',
#   'Latitude': '41.324086',
#   'Longitude': '-82.032995',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748252528',
#   'Title': 'TAuch_Infrastructure-Ross_HazardousWaste_Incinerator-LorainCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748252528/in/album-72157715916543893',
#   'Latitude': '41.325408',
#   'Longitude': '-82.034578',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52748252553',
#   'Title': 'TAuch_Infrastructure-Ross_HazardousWaste_Incinerator-LorainCounty-OH_March2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52748252553/in/album-72157715916543893',
#   'Latitude': '41.323647',
#   'Longitude': '-82.032459',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753719038',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting_WaterExpert_RobertBowcock-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52753719038/in/album-72157715916543893',
#   'Latitude': '40.839771',
#   'Longitude': '-80.545964',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52752690712',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting_ErinBrockovich-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52752690712/in/album-72157715916543893',
#   'Latitude': '40.839771',
#   'Longitude': '-80.545964',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753634955',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52753634955/in/album-72157715916543893',
#   'Latitude': '40.839771',
#   'Longitude': '-80.545964',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753470079',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52753470079/in/album-72157715916543893',
#   'Latitude': None,
#   'Longitude': None,
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753470124',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting_ProtestSignage-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52753470124/in/album-72157715916543893',
#   'Latitude': '40.839771',
#   'Longitude': '-80.545964',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753635115',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting_ProtestSignage-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52753635115/in/album-72157715916543893',
#   'Latitude': '40.839771',
#   'Longitude': '-80.545964',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753635155',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting_RWU_Member-ColumbianaCounty-OH_February2023',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2023.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/52753635155/in/album-72157715916543893',
#   'Latitude': '40.839771',
#   'Longitude': '-80.545964',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '52753227731',
#   'Title': 'TAuch_Community-EastPalestine_EducationalMeeting-ColumbianaCounty-OH_February2023',
# ...
#   'URL': 'https://www.flickr.com/photos/fractracker/49750328427/in/album-72157715916543893',
#   'Latitude': '41.283224',
#   'Longitude': '-77.398488',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '49770461356',
#   'Title': 'TAuch_Infrastructure-ImpoundmentPond_FrackPad-LycomingCounty_PA_LightHawk_Aug2019',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/49770461356/in/album-72157715916543893',
#   'Latitude': '41.290189',
#   'Longitude': '-77.385034',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '49770461616',
#   'Title': 'TAuch_Infrastructure-ImpoundmentPond_FrackPad-LycomingCounty_PA_LightHawk_Aug2019(2)',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/49770461616/in/album-72157715916543893',
#   'Latitude': '41.295671',
#   'Longitude': '-77.391300',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '49769921923',
#   'Title': 'TAuch_Infrastructure-ImpoundmentPond-LycomingCounty_PA_LightHawk_Aug2019(2)',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/49769921923/in/album-72157715916543893',
#   'Latitude': '41.291399',
#   'Longitude': '-77.392866',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '49769921573',
#   'Title': 'TAuch_Infrastructure-ImpoundmentPond-LycomingCounty_PA_LightHawk_Aug2019(4)',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/49769921573/in/album-72157715916543893',
#   'Latitude': '41.276419',
#   'Longitude': '-77.387866',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '49749824313',
#   'Title': 'TAuch_Infrastructure-FrackPad-LycomingCounty_PA_LightHawk_Aug2019',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/49749824313/in/album-72157715916543893',
#   'Latitude': '41.387659',
#   'Longitude': '-77.509059',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'},
#  {'PhotoID': '49770462716',
#   'Title': 'TAuch_Infrastructure-ImpoundmentPond_CompressorStation_FrackPad-LycomingCounty_PA_LightHawk_Aug2019',
#   'Description': 'Photo citation: Ted Auch, FracTracker Alliance, 2019. Aerial support provided by LightHawk.\n\nEach photo label provides this information, explained below: \n<i>Photographer_topic-sitespecific-siteowner-county-state_partneraffiliation_date(version)</i>\n\nPhoto labels provide information about what the image shows and where it was made. The label may describe the type of infrastructure pictured, the environment the photo captures, or the type of operations pictured. For many images, labels also provide site-specific information, including operators and facility names, if it is known by the photographer. \n\nAll photo labels include location information, at the state and county levels, and at township/village levels if it is helpful. Please make use of the geolocation data we provide - especially helpful if you want to see other imagery made nearby! \n\nWe encourage you to reach out to us about any imagery you wish to make use of, so that we can assist you in finding the best snapshots for your purposes, and so we can further explain these specific details to help you understand the imagery and fully describe it for your own purposes.\n\nPlease reach out to us at <b>info@fractracker.org</b> if you need more information about any of our images.\n\nFracTracker encourages you to use and share our imagery. Our resources can be used free of charge for noncommercial purposes, provided that the photo is cited in our format (found on each photo’s page). \n\nIf you wish to use our photos and/or videos for commercial purposes — including distributing them in publications for profit — please follow the steps on our <a href="https://www.flickr.com/people/fractracker/">‘About’ page</a>.\n\nAs a nonprofit, we work hard to gather and share our insights in publicly accessible ways. If you appreciate what you see here, follow us on Twitter, Instagram, or Facebook @fractracker, and donate if you can, at <a href="http://www.fractracker.org/donate" rel="noreferrer nofollow">www.fractracker.org/donate</a>!',
#   'URL': 'https://www.flickr.com/photos/fractracker/49770462716/in/album-72157715916543893',
#   'Latitude': '41.302861',
#   'Longitude': '-77.296113',
#   'AlbumID': '72157715916543893',
#   'AlbumTitle': 'Appalachian Buildout'}]

# %%
df = pd.DataFrame(attributes)
df
# Out:
#          PhotoID                                              Title  \
# 0    52748254383  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 1    52748254428  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 2    52748254383  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 3    52748254428  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# 4    52748254463  TAuch_Infrastructure-Heritage_HazardousWaste_I...
# ..           ...                                                ...
# 497  49770461616  TAuch_Infrastructure-ImpoundmentPond_FrackPad-...
# 498  49769921923  TAuch_Infrastructure-ImpoundmentPond-LycomingC...
# 499  49769921573  TAuch_Infrastructure-ImpoundmentPond-LycomingC...
# 500  49749824313  TAuch_Infrastructure-FrackPad-LycomingCounty_P...
# 501  49770462716  TAuch_Infrastructure-ImpoundmentPond_Compresso...
#
#                                            Description  \
# 0    Photo citation: Ted Auch, FracTracker Alliance...
# 1    Photo citation: Ted Auch, FracTracker Alliance...
# 2    Photo citation: Ted Auch, FracTracker Alliance...
# 3    Photo citation: Ted Auch, FracTracker Alliance...
# 4    Photo citation: Ted Auch, FracTracker Alliance...
# ..                                                 ...
# 497  Photo citation: Ted Auch, FracTracker Alliance...
# 498  Photo citation: Ted Auch, FracTracker Alliance...
# 499  Photo citation: Ted Auch, FracTracker Alliance...
# 500  Photo citation: Ted Auch, FracTracker Alliance...
# 501  Photo citation: Ted Auch, FracTracker Alliance...
#
#                                                    URL   Latitude   Longitude  \
# 0    https://www.flickr.com/photos/fractracker/5274...  40.631783  -80.546412
# 1    https://www.flickr.com/photos/fractracker/5274...  40.630638  -80.545881
# 2    https://www.flickr.com/photos/fractracker/5274...  40.631783  -80.546412
# 3    https://www.flickr.com/photos/fractracker/5274...  40.630638  -80.545881
# 4    https://www.flickr.com/photos/fractracker/5274...  40.631202  -80.545584
# ..                                                 ...        ...         ...
# 497  https://www.flickr.com/photos/fractracker/4977...  41.295671  -77.391300
# 498  https://www.flickr.com/photos/fractracker/4976...  41.291399  -77.392866
# 499  https://www.flickr.com/photos/fractracker/4976...  41.276419  -77.387866
# 500  https://www.flickr.com/photos/fractracker/4974...  41.387659  -77.509059
# 501  https://www.flickr.com/photos/fractracker/4977...  41.302861  -77.296113
#
#                AlbumID            AlbumTitle
# 0    72157715916543893  Appalachian Buildout
# 1    72157715916543893  Appalachian Buildout
# 2    72157715916543893  Appalachian Buildout
# 3    72157715916543893  Appalachian Buildout
# 4    72157715916543893  Appalachian Buildout
# ..                 ...                   ...
# 497  72157715916543893  Appalachian Buildout
# 498  72157715916543893  Appalachian Buildout
# 499  72157715916543893  Appalachian Buildout
# 500  72157715916543893  Appalachian Buildout
# 501  72157715916543893  Appalachian Buildout
#
# [502 rows x 8 columns]

# %%
pg_start,pg_end,first_lst=1,1,500
for a_id in album_ids:
    photos : JSONObject = flickr.photosets.getPhotos(photoset_id=a_id, per_page=first_lst, page=pg_start)
    pg_start,pg_end = photos['photoset']['page'],photos['photoset']['pages']
    attributes = []
    album_title = photos['photoset']['title']
    for album_pg in range(pg_start,pg_end+1):
